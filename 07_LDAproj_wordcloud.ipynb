# %%
# ---------------------------------- TITLE -------------------------------------
# 07_LDAproj_wordcloud.ipynb
# AUTHOR: HARUKA TAKAGI
# DATE: JULY 14, 2020
# ENCODING: utf-8
# PYTHON VERSION: 3.7

# ---------------------------------- NOTES -------------------------------------
# The purpose of this script is to create a word cloud for the FOMC historical
# documents.

# ---------------------------------- SETUP -------------------------------------

from wordcloud import WordCloud
import matplotlib.pyplot as plt 
import pandas as pd

# %%
# ---------------------------------- CODE --------------------------------------

# GREENBOOK_MINI
# Read in dataframe
dataframe = pd.read_csv("/Users/harukatakagi/Dropbox/FOMC_Board/FOMC_Historical_Materials_dataframe/Greenbook_mini.csv", encoding ="utf-8") 

# Join all text instances into one large string
text = " ".join(content for content in dataframe.text)

# Create and generate a word cloud image:
wordcloud = WordCloud(width = 2000, height = 1000, background_color="white").generate(text)
image = wordcloud.to_image()
image.save("/Users/harukatakagi/Dropbox/FOMC_Board/FOMC_Historical_Materials_STATS+WordClouds/greenbook_mini_wordcloud.png")


# GREENBOOK
# Read in dataframe
dataframe = pd.read_csv("/Users/harukatakagi/Dropbox/FOMC_Board/FOMC_Historical_Materials_dataframe/Greenbook.csv", encoding ="utf-8") 

# Join all text instances into one large string
text = " ".join(content for content in dataframe.text)

# Create and generate a word cloud image:
wordcloud = WordCloud(width = 2000, height = 1000, background_color="white").generate(text)
image = wordcloud.to_image()
image.save("/Users/harukatakagi/Dropbox/FOMC_Board/FOMC_Historical_Materials_STATS+WordClouds/greenbook_wordcloud.png")


# BLUEBOOK
# Read in dataframe
dataframe = pd.read_csv("/Users/harukatakagi/Dropbox/FOMC_Board/FOMC_Historical_Materials_dataframe/Bluebook.csv", encoding ="utf-8") 

# Join all text instances into one large string
text = " ".join(content for content in dataframe.text)

# Create and generate a word cloud image:
wordcloud = WordCloud(width = 2000, height = 1000, background_color="white").generate(text)
image = wordcloud.to_image()
image.save("/Users/harukatakagi/Dropbox/FOMC_Board/FOMC_Historical_Materials_STATS+WordClouds/bluebook_wordcloud.png")


# BEIGEBOOK
# Read in dataframe
dataframe = pd.read_csv("/Users/harukatakagi/Dropbox/FOMC_Board/FOMC_Historical_Materials_dataframe/Beigebook.csv", encoding ="utf-8") 

# Join all text instances into one large string
text = " ".join(content for content in dataframe.text)

# Create and generate a word cloud image:
wordcloud = WordCloud(width = 2000, height = 1000, background_color="white").generate(text)
image = wordcloud.to_image()
image.save("/Users/harukatakagi/Dropbox/FOMC_Board/FOMC_Historical_Materials_STATS+WordClouds/beigebook_wordcloud.png")


# TEALBOOK
# Read in dataframe
dataframe = pd.read_csv("/Users/harukatakagi/Dropbox/FOMC_Board/FOMC_Historical_Materials_dataframe/Tealbook.csv", encoding ="utf-8") 

# Join all text instances into one large string
text = " ".join(content for content in dataframe.text)

# Create and generate a word cloud image:
wordcloud = WordCloud(width = 2000, height = 1000, background_color="white").generate(text)
image = wordcloud.to_image()
image.save("/Users/harukatakagi/Dropbox/FOMC_Board/FOMC_Historical_Materials_STATS+WordClouds/tealbook_wordcloud.png")
